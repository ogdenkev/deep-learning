# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
# Count number of occurances of each word
word_counts = {}
for word in words:
    if word in word_counts:
        word_counts[word] += 1
    else:
        word_counts[word] = 1

# %%
## Create a dictionary of discard probabilities for easy lookup
# "t is a chosen threshold, typically around 10−5", from Distributed Representations of Words and Phrases
# and their Compositionality by Mikolov et al., section 2.2
threshold = 1e-5
tot_words = len(words)
word_freq = {w: word_counts[w] / tot_words for w in vocab_to_int}
prob_discard = {}
for w, f in word_freq.items():
    if f > threshold:
        prob_discard[w] = 1 - np.sqrt(threshold / f)
    else:
        prob_discard[w] = 0

# %%
train_words = []  # The final subsampled word list
for wrd in words:
    p_discard = prob_discard[wrd]
    if np.random.random() > p_discard:
        train_words.append(vocab_to_int[wrd])

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    r = np.random.randint(1, window_size+1)
    idx_start = idx - r
    if idx_start < 0:
        idx_start = 0
    idx_end = idx + r + 1
    # Skip the word itself
    word_set = set(words[idx_start:idx] + words[idx+1:idx_end])
    
    return list(word_set)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None])
    # labels = tf.placeholder(tf.int32, [len(vocab_to_int), 1])
    # Need to listen to solution video (hopefully it will says something about this)
    labels = tf.placeholder(tf.int32, [None, None])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200  # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding]))  # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)  # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # Note that for tf.nn.sampled_softmax_loss weights has shape [num_classes, dim]
    # and inputs has shape [batch_size, dim]
    # This is different that tf.matmul, where inputs would be [batch_size, dim] and weights would be [dim, num_classes]
    # softmax_w = tf.Variable(tf.truncated_normal([n_embedding, n_vocab]))
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding]))  # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))  # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights = softmax_w,
                                      biases  = softmax_b,
                                      labels  = labels,
                                      inputs  = embed,
                                      num_sampled = n_sampled,
                                      num_classes = n_vocab,
                                      num_true = 1)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random

with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 17.6104 0.0817 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 16.1848 0.0794 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 15.5485 0.0799 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 14.7796 0.0795 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 14.2714 0.0792 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 13.9687 0.0800 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 13.7250 0.0794 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 13.4685 0.0806 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 13.6406 0.0823 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 13.4977 0.0834 sec/batch
# Nearest to years: tonga, hih, rna, territory, alfons, cocktail, sibelius, query,
# Nearest to most: palin, elamite, hiragana, dimensionality, hillsborough, as, plasmid, specially,
# Nearest to states: decentralization, bins, kenji, verbatim, keeling, mcneill, cartridge, dribbling,
# Nearest to one: face, hibernate, emergency, fauvism, facial, csce, herself, similarly,
# Nearest to that: scholl, longa, forget, abyssinian, alcohol, bug, courtois, innsbruck,
# Nearest to more: hogarth, aznavour, lockheed, redskins, mannerism, immanence, conversions, dijon,
# Nearest to may: forget, alphonse, revolver, chet, obstinate, meng, pushes, unwelcome,
# Nearest to world: crawler, explore, baroness, bridge, georgy, ahlquist, canes, geodesics,
# Nearest to bible: bruford, sholom, boarding, caution, chewing, awkward, clos, devout,
# Nearest to marriage: relying, qigong, harrow, gabler, chlorine, paterson, instructional, fcc,
# Nearest to lived: cast, scholl, for, donatello, ctor, dishonest, inimitable, debut,
# Nearest to stage: achaemenid, disparaged, schooner, americanism, windshield, icebergs, radiochemical, variation,
# Nearest to derived: novaya, downtempo, prus, mythologies, potential, thereabouts, cried, debates,
# Nearest to taking: tweet, tycoon, hohlbein, lists, ewen, aykroyd, broadcaster, ruiz,
# Nearest to creation: licentious, bre, sark, drop, shinai, deer, margin, multilevel,
# Nearest to articles: filler, adjoint, dollfuss, pgs, ray, miami, cryopreserved, mujahedin,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 13.0433 0.0852 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 13.2019 0.0845 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 12.8415 0.0852 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 13.1445 0.0860 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 13.4099 0.0860 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 12.8744 0.0869 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 13.0384 0.0875 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 13.0886 0.0875 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 12.9790 0.0873 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 12.7257 0.0876 sec/batch
# Nearest to years: tonga, territory, hih, sibelius, query, cocktail, rna, alfons,
# Nearest to most: as, hiragana, elamite, dimensionality, example, these, hillsborough, classified,
# Nearest to states: was, keeling, kenji, decentralization, bins, cartridge, kahanism, site,
# Nearest to one: face, hibernate, emergency, fauvism, similarly, facial, friar, herself,
# Nearest to that: scholl, forget, ray, strawberry, longa, bug, abyssinian, adjacent,
# Nearest to more: hogarth, aznavour, attempt, authors, lockheed, mannerism, immanence, attaching,
# Nearest to may: forget, alphonse, ton, tells, directions, exercised, schumacher, unwelcome,
# Nearest to world: crawler, baroness, trivia, explore, bridge, hands, georgy, ahlquist,
# Nearest to bible: bruford, caution, then, sholom, are, enroll, spilled, plum,
# Nearest to marriage: relying, qigong, harrow, chlorine, gabler, spoken, paterson, instructional,
# Nearest to lived: for, cast, debut, donatello, scholl, destroyed, dishonest, ctor,
# Nearest to stage: for, disparaged, achaemenid, variation, schooner, two, americanism, windshield,
# Nearest to derived: potential, novaya, thereabouts, downtempo, mythologies, debates, have, prus,
# Nearest to taking: tweet, tycoon, lists, ewen, hohlbein, christendom, aykroyd, wet,
# Nearest to creation: licentious, usually, of, drop, shinai, five, sark, bre,
# Nearest to articles: have, filler, reaction, ray, dollfuss, pgs, forfeited, usually,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 12.6116 0.0895 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 12.6062 0.0884 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 12.8333 0.0888 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 12.7625 0.0880 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 12.7989 0.0883 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 12.4328 0.0888 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 12.3383 0.0882 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 12.6491 0.0885 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 12.5926 0.0889 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 12.1912 0.0887 sec/batch
# Nearest to years: tonga, territory, that, cocktail, have, query, hih, for,
# Nearest to most: as, these, example, not, hillsborough, number, classified, and,
# Nearest to states: was, keeling, kenji, most, decentralization, similar, dribbling, entire,
# Nearest to one: of, face, hibernate, produced, emergency, five, this, csce,
# Nearest to that: the, forget, in, for, two, have, rather, ray,
# Nearest to more: and, hogarth, aznavour, the, however, authors, attempt, of,
# Nearest to may: forget, the, that, tells, alphonse, meng, directions, obstinate,
# Nearest to world: baroness, that, why, crawler, bridge, hands, teaching, mouth,
# Nearest to bible: then, bruford, caution, are, there, great, enroll, sholom,
# Nearest to marriage: relying, qigong, spreading, to, life, gabler, spoken, which,
# Nearest to lived: for, cast, of, dishonest, destroyed, debut, donatello, ctor,
# Nearest to stage: for, two, achaemenid, schooner, variation, modest, benton, americanism,
# Nearest to derived: have, potential, that, debates, thereabouts, attempt, novaya, downtempo,
# Nearest to taking: tweet, vital, tycoon, major, wet, of, lists, christendom,
# Nearest to creation: five, usually, of, other, licentious, drop, silent, bre,
# Nearest to articles: have, which, reaction, deal, of, last, dollfuss, ray,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 12.2530 0.0902 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 12.1981 0.0895 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 11.8671 0.0902 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 12.2868 0.0903 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 11.8798 0.0905 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 12.4338 0.0897 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 12.0646 0.0897 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 12.1509 0.0894 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 12.0803 0.0894 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 11.9479 0.0899 sec/batch
# Nearest to years: tonga, have, that, territory, for, the, of, made,
# Nearest to most: as, and, the, number, these, not, a, for,
# Nearest to states: was, entire, similar, the, kenji, against, keeling, most,
# Nearest to one: of, five, the, and, which, this, two, to,
# Nearest to that: the, in, and, for, be, forget, these, s,
# Nearest to more: and, the, for, of, have, however, authors, in,
# Nearest to may: the, forget, that, tells, most, came, s, they,
# Nearest to world: the, that, by, of, with, why, zero, and,
# Nearest to bible: then, are, caution, the, of, bruford, they, great,
# Nearest to marriage: qigong, of, to, been, relying, s, which, and,
# Nearest to lived: for, cast, of, destroyed, with, debut, the, expectations,
# Nearest to stage: for, and, have, two, to, achaemenid, benton, only,
# Nearest to derived: have, parties, that, debates, attempt, highest, with, potential,
# Nearest to taking: to, of, with, that, tweet, for, through, vital,
# Nearest to creation: of, five, usually, other, the, silent, it, drop,
# Nearest to articles: have, reaction, the, of, own, which, last, usually,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 12.1660 0.0902 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 12.0924 0.0896 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 11.6231 0.0901 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 12.1000 0.0898 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 11.9541 0.0894 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 11.6626 0.0899 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 11.5086 0.0648 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 11.4133 0.0896 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 12.0679 0.0892 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 11.5204 0.0887 sec/batch
# Nearest to years: have, the, of, made, to, that, territory, tonga,
# Nearest to most: the, and, as, a, number, to, for, of,
# Nearest to states: was, the, against, to, of, entire, most, a,
# Nearest to one: the, of, to, five, and, four, s, two,
# Nearest to that: the, and, in, to, of, a, be, was,
# Nearest to more: and, the, of, a, for, in, as, are,
# Nearest to may: the, forget, that, and, early, of, to, tells,
# Nearest to world: the, of, that, by, and, zero, end, two,
# Nearest to bible: then, are, and, they, in, to, of, caution,
# Nearest to marriage: to, the, of, which, s, been, as, and,
# Nearest to lived: the, for, of, cast, a, to, s, destroyed,
# Nearest to stage: and, for, to, in, have, of, achaemenid, some,
# Nearest to derived: have, the, a, parties, of, debates, with, highest,
# Nearest to taking: of, to, a, the, and, be, that, with,
# Nearest to creation: usually, of, and, five, other, silent, the, mass,
# Nearest to articles: the, of, have, reaction, a, different, in, argued,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 11.4237 0.0899 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 11.5657 0.0889 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 11.5949 0.0897 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 11.3453 0.0887 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 11.4072 0.0887 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 11.4109 0.0896 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 10.7809 0.0898 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 10.8554 0.0899 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 10.7283 0.0903 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 10.9620 0.0907 sec/batch
# Nearest to years: the, and, for, in, of, to, have, s,
# Nearest to most: the, to, and, a, as, number, is, in,
# Nearest to states: was, the, in, of, against, and, a, to,
# Nearest to one: of, nine, zero, three, two, five, s, in,
# Nearest to that: and, the, a, in, of, to, is, was,
# Nearest to more: and, the, of, as, in, a, for, to,
# Nearest to may: and, the, in, forget, they, of, a, that,
# Nearest to world: the, and, zero, in, is, of, two, s,
# Nearest to bible: then, and, they, or, the, there, level, after,
# Nearest to marriage: which, the, and, to, a, as, is, zero,
# Nearest to lived: for, the, cast, to, of, a, and, in,
# Nearest to stage: in, and, for, to, the, some, s, from,
# Nearest to derived: have, the, of, parties, been, in, with, debates,
# Nearest to taking: and, of, the, in, was, to, that, a,
# Nearest to creation: and, the, usually, in, other, it, of, as,
# Nearest to articles: the, in, and, of, a, have, different, to,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 10.7665 0.0913 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 10.8419 0.0902 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 10.6365 0.0899 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 10.4484 0.0901 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 10.8703 0.0894 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 10.6238 0.0892 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 10.3646 0.0895 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 10.3795 0.0891 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 10.4996 0.0897 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 10.1193 0.0893 sec/batch
# Nearest to years: and, the, for, a, which, to, that, in,
# Nearest to most: to, is, can, for, by, and, a, in,
# Nearest to states: for, to, were, which, of, was, that, from,
# Nearest to one: zero, four, in, two, three, nine, eight, five,
# Nearest to that: the, to, a, as, and, in, of, is,
# Nearest to more: of, for, a, it, in, the, as, and,
# Nearest to may: and, for, as, was, they, in, the, an,
# Nearest to world: in, and, by, to, as, with, zero, or,
# Nearest to bible: they, or, then, that, level, another, certain, not,
# Nearest to marriage: for, of, in, as, a, the, to, with,
# Nearest to lived: with, for, cast, of, in, the, to, as,
# Nearest to stage: to, for, that, each, have, by, or, a,
# Nearest to derived: have, in, and, of, highest, that, parties, it,
# Nearest to taking: in, with, to, for, and, by, two, of,
# Nearest to creation: other, with, and, as, usually, it, for, on,
# Nearest to articles: and, of, by, for, to, in, the, on,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 10.8218 0.0904 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 9.9973 0.0889 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 10.1656 0.0894 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 10.6023 0.0891 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 10.2153 0.0887 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 9.9453 0.0890 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 9.8820 0.0897 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 9.7982 0.0895 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 9.9704 0.0903 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 9.6852 0.0902 sec/batch
# Nearest to years: the, to, after, by, but, from, have, s,
# Nearest to most: to, the, can, which, in, and, is, it,
# Nearest to states: to, it, from, by, which, some, the, are,
# Nearest to one: zero, three, two, five, seven, eight, nine, four,
# Nearest to that: the, a, it, in, on, are, of, to,
# Nearest to more: the, it, in, to, a, from, be, and,
# Nearest to may: the, in, it, are, for, be, that, on,
# Nearest to world: the, by, in, at, is, on, was, to,
# Nearest to bible: then, another, they, level, not, but, within, certain,
# Nearest to marriage: in, the, its, this, by, only, is, while,
# Nearest to lived: cast, its, in, as, the, was, top, had,
# Nearest to stage: each, to, some, different, with, only, could, have,
# Nearest to derived: in, a, the, is, s, of, was, from,
# Nearest to taking: all, to, would, not, of, in, the, but,
# Nearest to creation: usually, other, it, on, to, be, any, in,
# Nearest to articles: the, some, in, to, on, after, it, of,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 9.7876 0.0916 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 10.3250 0.0898 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 9.7002 0.0901 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 10.2926 0.0896 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 10.2300 0.0897 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 9.5763 0.0898 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 9.9522 0.0890 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 9.7061 0.0891 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 9.5930 0.0897 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 9.5517 0.0900 sec/batch
# Nearest to years: over, the, at, in, to, two, or, of,
# Nearest to most: is, to, the, can, of, for, are, or,
# Nearest to states: the, to, an, which, for, in, a, at,
# Nearest to one: nine, six, three, seven, four, five, eight, two,
# Nearest to that: to, and, the, have, is, of, this, as,
# Nearest to more: are, the, is, an, for, a, by, in,
# Nearest to may: the, or, be, on, not, of, it, was,
# Nearest to world: the, in, first, of, and, for, all, at,
# Nearest to bible: certain, level, seems, laid, within, every, then, another,
# Nearest to marriage: while, been, spreading, all, changed, example, then, yet,
# Nearest to lived: cast, top, his, later, maintain, previously, of, war,
# Nearest to stage: also, the, time, on, but, a, such, of,
# Nearest to derived: might, highest, parties, governed, without, is, since, true,
# Nearest to taking: although, states, during, to, of, the, its, time,
# Nearest to creation: usually, found, any, put, its, main, well, as,
# Nearest to articles: time, available, the, program, within, he, given, years,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 10.0989 0.0904 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 9.4257 0.0892 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 9.8118 0.0396 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 9.5655 0.0893 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 9.7063 0.0898 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 9.3779 0.0888 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 9.1889 0.0890 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 9.9075 0.0888 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 9.4075 0.0890 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 9.2881 0.0889 sec/batch
# Nearest to years: the, and, over, of, had, was, time, s,
# Nearest to most: to, is, the, and, which, more, as, of,
# Nearest to states: of, and, the, to, had, s, in, was,
# Nearest to one: two, five, nine, four, eight, six, seven, three,
# Nearest to that: of, to, the, a, and, is, as, not,
# Nearest to more: and, the, of, to, most, a, but, not,
# Nearest to may: to, and, of, not, the, which, this, it,
# Nearest to world: the, and, of, a, as, in, around, two,
# Nearest to bible: level, certain, then, along, laid, think, plays, behind,
# Nearest to marriage: we, by, to, the, spreading, and, made, is,
# Nearest to lived: cast, was, previously, the, and, local, during, of,
# Nearest to stage: only, situation, never, not, at, specifically, case, have,
# Nearest to derived: the, has, governed, made, parties, highest, had, and,
# Nearest to taking: and, of, states, to, it, the, is, this,
# Nearest to creation: in, any, several, was, this, would, great, eventually,
# Nearest to articles: and, time, the, for, late, program, this, within,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 9.2884 0.0905 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 9.2017 0.0894 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 8.9591 0.0898 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 9.0396 0.0902 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 8.9018 0.0905 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 8.8905 0.0906 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 9.1990 0.0897 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 8.8668 0.0905 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 8.6594 0.0898 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 9.1489 0.0904 sec/batch
# Nearest to years: to, in, the, would, of, at, was, a,
# Nearest to most: a, this, or, of, to, is, and, in,
# Nearest to states: united, a, and, the, an, there, this, was,
# Nearest to one: two, nine, four, five, eight, three, seven, zero,
# Nearest to that: a, to, of, is, be, this, or, some,
# Nearest to more: of, a, and, to, the, in, for, or,
# Nearest to may: a, of, for, the, to, any, and, have,
# Nearest to world: and, has, to, the, a, at, on, october,
# Nearest to bible: those, making, plays, seems, changing, early, behind, text,
# Nearest to marriage: a, the, bound, spreading, each, its, but, areas,
# Nearest to lived: cast, top, were, in, first, previously, to, their,
# Nearest to stage: when, to, a, well, the, case, never, specifically,
# Nearest to derived: despite, well, somewhat, in, none, might, political, a,
# Nearest to taking: that, with, in, to, a, on, special, became,
# Nearest to creation: however, public, to, on, a, by, of, have,
# Nearest to articles: a, when, and, in, the, of, an, s,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 8.8416 0.0909 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 9.4251 0.0895 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 8.4312 0.0899 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 8.7256 0.0900 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 9.0046 0.0895 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 8.7346 0.0896 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 8.6884 0.0897 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 8.9195 0.0891 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 8.4264 0.0891 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 8.4755 0.0893 sec/batch
# Nearest to years: the, of, zero, a, two, in, to, from,
# Nearest to most: the, to, with, in, of, many, has, it,
# Nearest to states: the, and, a, in, of, that, on, united,
# Nearest to one: zero, nine, two, five, three, eight, seven, six,
# Nearest to that: it, and, to, the, be, of, is, a,
# Nearest to more: of, to, in, and, a, the, is, this,
# Nearest to may: been, that, a, the, and, is, be, very,
# Nearest to world: of, and, the, in, has, a, to, on,
# Nearest to bible: think, dozens, contrast, text, mathematical, plays, and, explicitly,
# Nearest to marriage: of, spreading, mean, to, areas, many, beginning, the,
# Nearest to lived: of, the, top, seems, but, position, first, debut,
# Nearest to stage: of, situation, a, the, and, in, but, to,
# Nearest to derived: a, there, somewhat, others, more, and, extent, the,
# Nearest to taking: a, the, has, it, and, on, of, to,
# Nearest to creation: it, eventually, the, in, to, has, science, and,
# Nearest to articles: program, think, the, and, or, society, unusual, net,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 8.8622 0.0904 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 8.3060 0.0893 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 8.4655 0.0899 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 8.6512 0.0893 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 8.5203 0.0903 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 8.3277 0.0904 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 8.1121 0.0902 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 8.4326 0.0902 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 8.2194 0.0894 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 8.3730 0.0897 sec/batch
# Nearest to years: the, was, and, a, of, s, in, zero,
# Nearest to most: of, to, the, and, a, is, with, that,
# Nearest to states: united, the, a, to, of, that, for, and,
# Nearest to one: eight, nine, five, seven, two, zero, three, four,
# Nearest to that: to, the, a, for, of, on, and, it,
# Nearest to more: of, the, and, a, is, to, this, for,
# Nearest to may: be, are, the, is, a, on, all, which,
# Nearest to world: of, the, a, and, on, for, be, in,
# Nearest to bible: the, text, think, explicitly, of, dozens, disappeared, mathematical,
# Nearest to marriage: spreading, areas, mean, vastly, to, exactly, and, but,
# Nearest to lived: the, a, in, of, and, were, was, to,
# Nearest to stage: situation, of, to, a, is, an, and, notions,
# Nearest to derived: must, abandoned, a, from, which, and, is, gain,
# Nearest to taking: a, the, of, as, they, to, several, is,
# Nearest to creation: move, to, of, in, both, a, began, be,
# Nearest to articles: a, think, and, the, to, issue, position, unusual,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 9.0350 0.0909 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 8.0238 0.0901 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 8.6728 0.0893 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 8.4583 0.0892 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 8.3402 0.0897 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 8.2475 0.0897 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 8.2372 0.0891 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 8.3960 0.0893 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 8.3070 0.0150 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 8.3499 0.0892 sec/batch
# Nearest to years: five, population, six, one, of, also, two, zero,
# Nearest to most: of, and, the, to, in, as, this, a,
# Nearest to states: of, the, and, to, a, in, s, by,
# Nearest to one: four, six, nine, five, seven, two, three, zero,
# Nearest to that: of, to, the, a, in, be, it, is,
# Nearest to more: of, on, the, is, by, in, to, a,
# Nearest to may: to, of, and, a, for, there, in, the,
# Nearest to world: the, of, to, by, and, is, as, was,
# Nearest to bible: text, depends, laid, chalk, half, this, intentions, experimented,
# Nearest to marriage: to, the, of, for, agree, catholic, spreading, but,
# Nearest to lived: his, germany, by, the, of, became, but, its,
# Nearest to stage: in, notions, situation, for, signing, to, chinese, by,
# Nearest to derived: general, from, which, had, the, of, between, it,
# Nearest to taking: to, the, is, a, of, in, be, its,
# Nearest to creation: their, move, and, with, in, speech, situations, available,
# Nearest to articles: ranking, acceptable, whatever, foreign, tremendous, bombing, issue, think,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 8.2840 0.0906 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 8.4029 0.0885 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 7.9189 0.0887 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 8.3616 0.0886 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 8.3673 0.0889 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 7.9840 0.0889 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 7.9024 0.0893 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 8.0692 0.0895 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 7.8985 0.0898 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 7.5764 0.0901 sec/batch
# Nearest to years: in, zero, of, the, with, s, during, is,
# Nearest to most: the, and, a, of, is, to, in, from,
# Nearest to states: of, the, in, to, is, and, a, as,
# Nearest to one: nine, two, five, six, three, seven, eight, four,
# Nearest to that: of, to, is, in, and, as, the, by,
# Nearest to more: as, in, of, and, to, the, is, a,
# Nearest to may: of, to, which, is, and, in, a, the,
# Nearest to world: the, of, in, and, as, is, with, five,
# Nearest to bible: text, tanakh, chalk, depends, to, testament, of, christians,
# Nearest to marriage: is, suffer, unless, to, not, of, spreading, vastly,
# Nearest to lived: the, of, in, to, when, not, and, after,
# Nearest to stage: in, of, cover, conduct, progress, mean, the, to,
# Nearest to derived: are, is, of, that, on, s, as, a,
# Nearest to taking: and, to, from, is, of, general, in, as,
# Nearest to creation: in, belief, and, attend, seeking, of, situations, as,
# Nearest to articles: whatever, ranking, delivered, acceptable, of, s, integrate, people,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 7.7344 0.0916 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 7.7199 0.0907 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 8.0919 0.0901 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 7.9458 0.0899 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 7.5054 0.0899 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 7.6728 0.0903 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 7.8590 0.0900 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 8.0597 0.0892 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 7.8177 0.0893 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 7.6378 0.0896 sec/batch
# Nearest to years: was, with, of, in, the, a, to, s,
# Nearest to most: the, is, that, of, by, at, and, to,
# Nearest to states: the, in, and, to, of, have, has, this,
# Nearest to one: two, four, nine, five, three, eight, of, zero,
# Nearest to that: the, a, to, is, in, or, have, of,
# Nearest to more: of, the, in, to, and, a, is, it,
# Nearest to may: the, if, it, in, to, this, a, is,
# Nearest to world: of, in, the, and, by, to, is, an,
# Nearest to bible: testament, tanakh, jewish, depends, christianity, chalk, laid, literary,
# Nearest to marriage: of, was, the, competitions, at, vastly, to, with,
# Nearest to lived: was, s, the, and, of, in, one, with,
# Nearest to stage: to, of, not, other, at, polar, interested, measuring,
# Nearest to derived: a, by, and, early, similar, of, its, fact,
# Nearest to taking: time, was, the, of, to, a, in, for,
# Nearest to creation: it, belief, in, was, seeking, but, meanwhile, of,
# Nearest to articles: whatever, of, ranking, delivered, in, the, input, freedom,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 7.8905 0.0908 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 7.6991 0.0897 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 7.6002 0.0896 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 8.0107 0.0894 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 7.4207 0.0897 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 7.4943 0.0898 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 7.7051 0.0893 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 7.6811 0.0897 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 7.6150 0.0896 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 7.6121 0.0897 sec/batch
# Nearest to years: to, time, have, zero, two, the, in, s,
# Nearest to most: the, in, as, that, be, of, to, more,
# Nearest to states: in, over, to, the, became, of, has, most,
# Nearest to one: two, nine, eight, seven, six, zero, to, three,
# Nearest to that: in, a, the, most, but, be, of, as,
# Nearest to more: most, the, to, for, but, of, time, and,
# Nearest to may: the, a, as, of, is, to, not, be,
# Nearest to world: to, the, a, in, of, and, most, is,
# Nearest to bible: the, testament, tanakh, jewish, of, depends, chalk, a,
# Nearest to marriage: vastly, the, an, marry, by, is, scientific, not,
# Nearest to lived: in, with, by, most, one, was, two, the,
# Nearest to stage: on, to, the, of, a, any, be, or,
# Nearest to derived: a, of, as, from, and, it, the, modern,
# Nearest to taking: the, to, in, these, be, that, as, what,
# Nearest to creation: of, a, in, states, was, the, over, most,
# Nearest to articles: the, on, to, however, consecutive, article, for, a,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 7.8034 0.0914 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 7.2486 0.0912 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 7.2814 0.0902 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 7.7178 0.0903 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 7.4981 0.0898 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 7.5171 0.0897 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 8.2638 0.0896 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 7.3265 0.0902 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 7.6343 0.0897 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 7.7601 0.0895 sec/batch
# Nearest to years: four, zero, s, two, and, three, age, have,
# Nearest to most: of, to, in, a, the, this, and, for,
# Nearest to states: of, to, the, a, united, and, in, s,
# Nearest to one: nine, four, two, six, three, eight, five, zero,
# Nearest to that: to, the, more, a, of, is, in, it,
# Nearest to more: to, the, that, it, is, of, a, for,
# Nearest to may: a, to, which, the, of, it, is, for,
# Nearest to world: of, and, the, in, for, a, to, s,
# Nearest to bible: chalk, testament, tanakh, bid, cognitive, the, breach, since,
# Nearest to marriage: marry, time, only, his, document, to, s, states,
# Nearest to lived: was, of, in, the, s, he, which, and,
# Nearest to stage: a, the, setting, from, over, it, for, point,
# Nearest to derived: of, use, which, also, is, are, since, in,
# Nearest to taking: in, of, all, s, an, for, to, a,
# Nearest to creation: s, this, a, as, states, the, and, to,
# Nearest to articles: this, all, s, charge, of, as, search, to,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 7.4094 0.0904 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 7.4428 0.0903 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 7.4744 0.0896 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 7.3058 0.0896 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 7.8757 0.0896 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 7.4493 0.0796 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 7.2831 0.0897 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 7.7174 0.0893 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 7.1546 0.0886 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 7.4351 0.0889 sec/batch
# Nearest to years: of, and, to, the, its, also, over, was,
# Nearest to most: to, in, the, by, for, as, of, is,
# Nearest to states: of, to, and, the, as, in, for, a,
# Nearest to one: eight, seven, nine, six, two, four, five, three,
# Nearest to that: the, to, is, a, there, and, of, as,
# Nearest to more: to, as, this, a, the, or, there, was,
# Nearest to may: a, to, the, of, are, as, and, in,
# Nearest to world: the, in, of, to, and, war, many, on,
# Nearest to bible: testament, tanakh, by, a, their, biblical, sharing, dont,
# Nearest to marriage: children, marry, divorce, both, made, his, had, states,
# Nearest to lived: in, on, was, who, of, became, the, to,
# Nearest to stage: in, to, on, from, of, by, for, the,
# Nearest to derived: as, of, known, about, its, the, in, from,
# Nearest to taking: to, in, the, of, and, a, most, as,
# Nearest to creation: by, in, to, an, made, for, a, the,
# Nearest to articles: law, countries, to, charge, and, failures, states, from,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 7.4671 0.0907 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 7.1135 0.0895 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 7.2453 0.0890 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 7.2541 0.0892 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 7.3807 0.0898 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 7.0258 0.0905 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 6.9646 0.0905 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 7.0508 0.0905 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 6.9822 0.0908 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 7.4032 0.0906 sec/batch
# Nearest to years: zero, in, five, two, the, six, one, and,
# Nearest to most: the, in, of, a, to, which, and, be,
# Nearest to states: in, and, of, to, it, the, from, as,
# Nearest to one: two, nine, three, seven, eight, zero, six, five,
# Nearest to that: in, and, a, or, the, of, is, to,
# Nearest to more: and, of, a, the, with, be, in, or,
# Nearest to may: of, a, not, other, in, and, it, as,
# Nearest to world: in, the, of, a, with, and, s, to,
# Nearest to bible: testament, tanakh, biblical, christians, jewish, orthodox, it, scripture,
# Nearest to marriage: marry, divorce, one, husband, many, plantation, that, is,
# Nearest to lived: by, at, and, between, time, was, on, of,
# Nearest to stage: with, was, time, usually, it, in, around, up,
# Nearest to derived: for, and, of, in, which, is, a, sense,
# Nearest to taking: in, when, a, for, of, world, about, it,
# Nearest to creation: was, of, in, as, at, death, its, by,
# Nearest to articles: in, a, and, its, s, was, of, an,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 6.9679 0.0910 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 7.1284 0.0902 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 7.2915 0.0901 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 7.3916 0.0895 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 7.1385 0.0896 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 6.9389 0.0895 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 6.9590 0.0898 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 7.2786 0.0905 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 6.7404 0.0897 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 7.1313 0.0892 sec/batch
# Nearest to years: zero, s, the, year, two, in, there, of,
# Nearest to most: a, the, to, be, with, are, or, and,
# Nearest to states: the, and, in, of, to, has, a, from,
# Nearest to one: nine, eight, five, seven, four, three, two, six,
# Nearest to that: to, a, and, be, the, for, which, is,
# Nearest to more: the, to, it, and, for, of, be, in,
# Nearest to may: in, was, of, a, the, more, with, for,
# Nearest to world: in, the, to, a, for, an, of, and,
# Nearest to bible: testament, tanakh, jewish, christians, scriptures, a, chalk, scripture,
# Nearest to marriage: marry, was, with, in, a, divorce, work, first,
# Nearest to lived: also, s, found, he, on, in, and, a,
# Nearest to stage: in, the, of, work, by, to, from, is,
# Nearest to derived: has, in, the, and, of, same, from, an,
# Nearest to taking: in, other, the, a, to, has, it, when,
# Nearest to creation: in, s, made, with, by, claim, was, first,
# Nearest to articles: online, an, about, and, working, other, or, of,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 6.9289 0.0907 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 6.7074 0.0892 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 7.2192 0.0893 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 6.8418 0.0897 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 6.8874 0.0896 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 7.0737 0.0891 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 7.0584 0.0898 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 6.7573 0.0906 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 6.9017 0.0903 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 6.7416 0.0908 sec/batch
# Nearest to years: zero, one, five, and, six, the, s, four,
# Nearest to most: the, in, to, of, on, but, and, by,
# Nearest to states: the, it, and, in, all, united, with, a,
# Nearest to one: three, nine, seven, five, four, six, zero, two,
# Nearest to that: the, and, this, to, a, is, of, it,
# Nearest to more: a, this, the, to, is, and, of, that,
# Nearest to may: not, in, to, of, the, for, it, other,
# Nearest to world: in, the, to, and, many, of, s, on,
# Nearest to bible: testament, tanakh, in, of, to, and, the, books,
# Nearest to marriage: s, in, she, time, lack, was, his, later,
# Nearest to lived: in, great, of, and, to, s, the, there,
# Nearest to stage: with, on, out, the, s, time, was, and,
# Nearest to derived: is, a, number, it, with, or, can, about,
# Nearest to taking: with, that, from, the, and, of, when, would,
# Nearest to creation: the, from, with, to, later, in, first, many,
# Nearest to articles: as, he, s, the, in, to, been, an,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 7.0276 0.0914 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 6.8331 0.0897 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 7.2225 0.0895 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 7.0719 0.0895 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 6.8049 0.0904 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 7.1259 0.0897 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 6.8774 0.0900 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 6.9690 0.0900 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 6.6843 0.0901 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 6.9278 0.0894 sec/batch
# Nearest to years: zero, three, live, two, of, six, population, under,
# Nearest to most: of, the, and, in, to, a, by, as,
# Nearest to states: of, from, its, the, to, there, for, and,
# Nearest to one: nine, six, eight, zero, seven, four, two, three,
# Nearest to that: a, the, or, of, it, is, for, to,
# Nearest to more: a, or, is, are, to, this, in, the,
# Nearest to may: not, to, of, for, and, are, a, on,
# Nearest to world: of, to, war, on, from, the, as, in,
# Nearest to bible: tanakh, testament, and, of, a, as, on, in,
# Nearest to marriage: time, the, for, church, religious, own, within, and,
# Nearest to lived: of, when, world, war, east, s, his, the,
# Nearest to stage: as, there, to, his, was, for, the, in,
# Nearest to derived: is, fact, also, in, s, of, since, to,
# Nearest to taking: general, of, the, also, as, to, in, is,
# Nearest to creation: from, end, first, the, for, to, which, and,
# Nearest to articles: in, the, on, from, own, of, there, and,
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 6.9040 0.0906 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 6.9040 0.0545 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 6.8886 0.0898 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 6.9392 0.0892 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 6.7207 0.0889 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 6.8654 0.0889 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 7.0168 0.0891 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 6.9407 0.0893 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 6.5393 0.0897 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 6.7020 0.0896 sec/batch
# Nearest to years: over, were, the, and, by, zero, time, in,
# Nearest to most: of, is, and, for, by, its, than, the,
# Nearest to states: and, the, of, in, is, to, by, a,
# Nearest to one: nine, three, six, seven, four, two, five, eight,
# Nearest to that: to, a, it, of, the, is, would, be,
# Nearest to more: as, is, there, or, a, that, the, are,
# Nearest to may: to, a, is, that, the, and, as, of,
# Nearest to world: of, in, the, and, to, as, s, a,
# Nearest to bible: testament, books, text, tanakh, scripture, translations, hebrew, scholars,
# Nearest to marriage: by, not, were, of, was, children, him, though,
# Nearest to lived: of, was, the, life, world, after, in, by,
# Nearest to stage: of, about, up, in, there, by, for, became,
# Nearest to derived: of, and, only, in, to, the, those, a,
# Nearest to taking: of, and, to, the, with, as, were, is,
# Nearest to creation: in, the, of, and, this, were, by, on,
# Nearest to articles: in, two, history, the, of, for, and, zero,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 6.9100 0.0909 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 6.4197 0.0903 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 6.5449 0.0901 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 6.6985 0.0906 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 6.7978 0.0914 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 6.8854 0.0903 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 6.5438 0.0901 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 6.6058 0.0902 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 6.5407 0.0904 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 6.7557 0.0901 sec/batch
# Nearest to years: to, a, and, states, the, were, in, with,
# Nearest to most: to, as, for, the, that, and, used, this,
# Nearest to states: the, to, of, in, and, were, united, on,
# Nearest to one: eight, four, seven, nine, five, two, six, three,
# Nearest to that: the, to, of, in, as, be, a, or,
# Nearest to more: the, as, of, or, to, in, with, and,
# Nearest to may: the, this, is, to, a, have, not, these,
# Nearest to world: and, in, the, to, with, was, of, it,
# Nearest to bible: testament, scholars, christian, christianity, second, books, christians, jewish,
# Nearest to marriage: marry, his, was, the, husband, many, man, persecution,
# Nearest to lived: was, the, his, s, in, by, of, one,
# Nearest to stage: it, time, these, during, the, an, in, be,
# Nearest to derived: the, a, of, as, second, is, by, in,
# Nearest to taking: in, the, as, to, with, who, of, be,
# Nearest to creation: earth, traditional, in, for, the, there, their, view,
# Nearest to articles: in, and, states, for, of, as, the, known,
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 6.7159 0.0916 sec/batch
# Epoch 6/10 Iteration: 25200 Avg. Training loss: 6.3124 0.0894 sec/batch
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 6.5416 0.0897 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 6.6756 0.0901 sec/batch
# Epoch 6/10 Iteration: 25500 Avg. Training loss: 6.4052 0.0897 sec/batch
# Epoch 6/10 Iteration: 25600 Avg. Training loss: 6.8576 0.0895 sec/batch
# Epoch 6/10 Iteration: 25700 Avg. Training loss: 6.6391 0.0895 sec/batch
# Epoch 6/10 Iteration: 25800 Avg. Training loss: 6.3329 0.0901 sec/batch
# Epoch 6/10 Iteration: 25900 Avg. Training loss: 6.5034 0.0897 sec/batch
# Epoch 6/10 Iteration: 26000 Avg. Training loss: 6.9122 0.0892 sec/batch
# Nearest to years: zero, a, in, one, the, under, over, nine,
# Nearest to most: in, the, to, of, a, are, as, for,
# Nearest to states: united, the, of, in, a, from, both, state,
# Nearest to one: nine, eight, two, seven, five, three, six, zero,
# Nearest to that: to, a, of, the, in, and, be, with,
# Nearest to more: to, a, the, that, of, and, are, in,
# Nearest to may: a, in, more, the, to, be, of, and,
# Nearest to world: in, the, and, a, on, to, major, zero,
# Nearest to bible: testament, jewish, biblical, christians, christianity, church, other, christian,
# Nearest to marriage: with, to, in, the, that, mother, own, a,
# Nearest to lived: in, on, was, other, new, whom, the, s,
# Nearest to stage: for, an, to, with, the, work, and, was,
# Nearest to derived: a, time, the, of, as, today, from, by,
# Nearest to taking: and, they, of, that, to, the, in, a,
# Nearest to creation: in, to, be, with, these, the, individual, a,
# Nearest to articles: also, the, of, article, a, online, to, published,
# Epoch 6/10 Iteration: 26100 Avg. Training loss: 6.3348 0.0907 sec/batch
# Epoch 6/10 Iteration: 26200 Avg. Training loss: 6.5160 0.0892 sec/batch
# Epoch 6/10 Iteration: 26300 Avg. Training loss: 6.4553 0.0895 sec/batch
# Epoch 6/10 Iteration: 26400 Avg. Training loss: 6.3958 0.0904 sec/batch
# Epoch 6/10 Iteration: 26500 Avg. Training loss: 6.3275 0.0903 sec/batch
# Epoch 6/10 Iteration: 26600 Avg. Training loss: 6.2548 0.0904 sec/batch
# Epoch 6/10 Iteration: 26700 Avg. Training loss: 6.5444 0.0899 sec/batch
# Epoch 6/10 Iteration: 26800 Avg. Training loss: 6.3014 0.0894 sec/batch
# Epoch 6/10 Iteration: 26900 Avg. Training loss: 6.5789 0.0894 sec/batch
# Epoch 6/10 Iteration: 27000 Avg. Training loss: 6.8535 0.0892 sec/batch
# Nearest to years: in, zero, two, and, was, of, a, s,
# Nearest to most: of, that, it, and, is, the, for, to,
# Nearest to states: and, united, of, from, a, to, the, at,
# Nearest to one: nine, seven, five, eight, four, six, two, zero,
# Nearest to that: it, with, is, for, the, this, to, be,
# Nearest to more: it, a, this, is, to, some, for, be,
# Nearest to may: this, be, it, is, that, not, but, the,
# Nearest to world: at, of, war, the, new, for, us, in,
# Nearest to bible: church, god, christian, view, at, the, as, brought,
# Nearest to marriage: he, civil, had, this, for, and, involved, they,
# Nearest to lived: had, was, he, and, at, in, a, it,
# Nearest to stage: a, from, to, making, with, for, be, more,
# Nearest to derived: and, including, the, with, of, is, for, most,
# Nearest to taking: to, it, of, from, the, a, for, they,
# Nearest to creation: a, for, all, with, by, the, public, as,
# Nearest to articles: an, for, on, from, to, he, at, the,
# Epoch 6/10 Iteration: 27100 Avg. Training loss: 6.4155 0.0907 sec/batch
# Epoch 6/10 Iteration: 27200 Avg. Training loss: 6.8276 0.0891 sec/batch
# Epoch 6/10 Iteration: 27300 Avg. Training loss: 6.5325 0.0891 sec/batch
# Epoch 6/10 Iteration: 27400 Avg. Training loss: 6.4517 0.0890 sec/batch
# Epoch 6/10 Iteration: 27500 Avg. Training loss: 6.4527 0.0897 sec/batch
# Epoch 6/10 Iteration: 27600 Avg. Training loss: 6.4593 0.0890 sec/batch
# Epoch 6/10 Iteration: 27700 Avg. Training loss: 6.3875 0.0892 sec/batch
# Epoch 7/10 Iteration: 27800 Avg. Training loss: 6.3818 0.0293 sec/batch
# Epoch 7/10 Iteration: 27900 Avg. Training loss: 6.3919 0.0893 sec/batch
# Epoch 7/10 Iteration: 28000 Avg. Training loss: 6.5283 0.0892 sec/batch
# Nearest to years: zero, population, two, s, the, to, from, its,
# Nearest to most: a, and, not, to, the, be, as, of,
# Nearest to states: the, of, and, a, by, in, state, as,
# Nearest to one: nine, eight, four, six, three, seven, five, two,
# Nearest to that: to, a, be, not, it, of, and, with,
# Nearest to more: the, as, of, a, with, be, to, this,
# ...
# Epoch 9/10 Iteration: 37300 Avg. Training loss: 6.0666 0.0888 sec/batch
# Epoch 9/10 Iteration: 37400 Avg. Training loss: 5.6352 0.0884 sec/batch
# Epoch 9/10 Iteration: 37500 Avg. Training loss: 5.8785 0.0885 sec/batch
# Epoch 9/10 Iteration: 37600 Avg. Training loss: 5.8055 0.0889 sec/batch
# Epoch 9/10 Iteration: 37700 Avg. Training loss: 5.6260 0.0896 sec/batch
# Epoch 9/10 Iteration: 37800 Avg. Training loss: 5.7106 0.0895 sec/batch
# Epoch 9/10 Iteration: 37900 Avg. Training loss: 5.6830 0.0895 sec/batch
# Epoch 9/10 Iteration: 38000 Avg. Training loss: 5.8126 0.0894 sec/batch
# Nearest to years: over, the, and, in, s, by, year, from,
# Nearest to most: a, as, is, or, the, more, that, it,
# Nearest to states: of, in, kingdom, united, the, s, was, and,
# Nearest to one: two, nine, seven, three, six, four, eight, five,
# Nearest to that: to, it, they, as, be, the, a, of,
# Nearest to more: as, it, most, to, a, is, its, and,
# Nearest to may: is, are, for, a, be, it, this, or,
# Nearest to world: in, the, as, of, was, and, zero, a,
# Nearest to bible: testament, tanakh, hebrew, biblical, books, text, texts, christian,
# Nearest to marriage: marry, parents, him, husband, children, religious, who, men,
# Nearest to lived: after, soon, who, their, in, th, history, of,
# Nearest to stage: by, would, on, in, when, first, is, place,
# Nearest to derived: is, as, are, such, any, idea, a, that,
# Nearest to taking: as, time, a, to, the, all, by, of,
# Nearest to creation: that, some, of, a, been, do, although, not,
# Nearest to articles: history, and, on, of, by, the, first, an,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 5.5765 0.0911 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 5.4673 0.0904 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 5.5443 0.0907 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 5.6751 0.0912 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 5.9522 0.0900 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 5.5590 0.0902 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 5.7251 0.0902 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 5.5760 0.0903 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 5.8207 0.0900 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 5.6086 0.0900 sec/batch
# Nearest to years: and, under, was, two, after, zero, age, s,
# Nearest to most: the, for, to, also, a, is, and, in,
# Nearest to states: united, state, new, capital, was, kingdom, world, were,
# Nearest to one: five, three, four, seven, two, eight, six, nine,
# Nearest to that: the, a, this, of, not, have, an, some,
# Nearest to more: the, for, to, of, a, than, is, as,
# Nearest to may: are, be, is, can, this, some, to, not,
# Nearest to world: the, were, s, and, in, was, by, during,
# Nearest to bible: testament, biblical, texts, hebrew, scholars, scripture, scriptures, christians,
# Nearest to marriage: marry, religious, church, himself, was, death, jewish, marriages,
# Nearest to lived: was, had, founded, stayed, during, who, people, s,
# Nearest to stage: the, time, and, several, at, happened, it, an,
# Nearest to derived: have, be, this, word, is, form, often, are,
# Nearest to taking: the, as, of, with, and, were, time, it,
# Nearest to creation: that, them, created, without, the, said, some, genesis,
# Nearest to articles: of, in, the, for, an, history, about, article,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 5.4519 0.0912 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 5.5512 0.0904 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 5.6938 0.0899 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 5.4583 0.0895 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 5.7918 0.0893 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 5.4945 0.0892 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 5.3184 0.0892 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 5.5863 0.0893 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 5.6176 0.0894 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 5.4637 0.0895 sec/batch
# Nearest to years: zero, five, age, six, at, birth, year, two,
# Nearest to most: to, in, of, the, this, from, a, many,
# Nearest to states: united, government, state, national, u, union, policy, member,
# Nearest to one: nine, six, eight, five, four, seven, two, three,
# Nearest to that: not, some, it, to, a, be, but, many,
# Nearest to more: to, a, some, has, an, is, be, are,
# Nearest to may: some, be, does, not, more, these, it, a,
# Nearest to world: in, the, s, since, over, from, of, and,
# Nearest to bible: testament, christian, jesus, christians, scripture, christianity, christ, god,
# Nearest to marriage: religious, mother, was, who, had, his, him, parents,
# Nearest to lived: in, was, the, had, became, of, who, new,
# Nearest to stage: on, a, to, in, the, first, would, an,
# Nearest to derived: some, from, a, modern, common, there, most, an,
# Nearest to taking: these, in, many, to, the, of, that, a,
# Nearest to creation: some, been, these, itself, self, work, not, as,
# Nearest to articles: on, also, links, in, for, by, online, comprehensive,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 5.5594 0.0905 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 5.5849 0.0903 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 5.4171 0.0907 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 5.5900 0.0903 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 5.3961 0.0911 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 5.6163 0.0899 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 5.4598 0.0898 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 5.8156 0.0895 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 5.8627 0.0895 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 5.4282 0.0902 sec/batch
# Nearest to years: birth, zero, population, age, four, female, two, male,
# Nearest to most: of, and, for, in, the, from, has, as,
# Nearest to states: united, u, in, member, national, state, was, the,
# Nearest to one: nine, eight, six, seven, three, five, two, four,
# Nearest to that: be, as, to, not, this, a, it, they,
# Nearest to more: is, it, be, as, that, or, are, generally,
# Nearest to may: be, a, it, as, to, for, there, that,
# Nearest to world: in, and, of, new, the, s, a, states,
# Nearest to bible: testament, texts, god, scripture, translation, book, jesus, tanakh,
# Nearest to marriage: divorce, mother, later, religious, had, who, did, was,
# Nearest to lived: his, was, he, new, of, death, had, s,
# Nearest to stage: on, a, release, as, their, and, the, they,
# Nearest to derived: there, is, are, meaning, forms, not, words, used,
# Nearest to taking: it, to, as, the, when, with, this, a,
# Nearest to creation: as, to, a, that, only, it, with, for,
# Nearest to articles: a, and, in, on, the, for, official, of,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 5.6703 0.0907 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 5.5778 0.0900 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 5.3703 0.0901 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 5.4552 0.0903 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 5.4764 0.0901 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 5.6027 0.0893 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 5.5086 0.0433 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 5.4965 0.0896 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 5.5893 0.0892 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 5.5264 0.0889 sec/batch
# Nearest to years: year, during, from, the, months, and, age, of,
# Nearest to most: the, with, of, and, to, for, from, which,
# Nearest to states: state, united, of, established, government, the, member, union,
# Nearest to one: nine, seven, six, eight, five, four, three, two,
# Nearest to that: not, with, to, be, such, but, a, all,
# Nearest to more: this, there, a, than, it, is, an, and,
# Nearest to may: is, with, not, a, that, there, as, all,
# Nearest to world: the, in, and, of, from, by, s, until,
# Nearest to bible: hebrew, testament, tanakh, scripture, texts, christian, biblical, scriptures,
# Nearest to marriage: divorce, he, marriages, who, mother, father, his, himself,
# Nearest to lived: he, was, who, in, took, became, his, last,
# Nearest to stage: first, at, the, on, for, to, and, s,
# Nearest to derived: language, there, as, most, term, meaning, other, modern,
# Nearest to taking: to, a, the, it, of, is, and, with,
# Nearest to creation: give, what, which, well, but, been, with, many,
# Nearest to articles: in, on, the, new, s, of, history, and,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 5.4935 0.0901 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 5.6551 0.0890 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 5.4656 0.0894 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 5.3269 0.0900 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 5.3621 0.0895 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 5.5847 0.0898 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 5.4298 0.0906 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 5.2758 0.0906 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 5.3333 0.0909 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 5.2359 0.0905 sec/batch
# Nearest to years: age, zero, s, five, under, two, year, over,
# Nearest to most: in, to, the, a, as, of, that, this,
# Nearest to states: state, united, government, of, established, kingdom, was, union,
# Nearest to one: nine, four, five, seven, eight, three, two, six,
# Nearest to that: a, be, it, to, there, this, the, in,
# Nearest to more: to, are, a, and, which, other, than, is,
# Nearest to may: for, which, or, these, must, often, thus, is,
# Nearest to world: in, s, the, of, over, from, during, first,
# Nearest to bible: hebrew, testament, tanakh, prophets, book, biblical, christian, scripture,
# Nearest to marriage: divorce, his, father, mother, christians, he, marriages, him,
# Nearest to lived: was, were, became, had, after, sent, died, took,
# Nearest to stage: time, first, by, playing, only, at, from, occasions,
# Nearest to derived: forms, is, word, are, which, other, meaning, language,
# Nearest to taking: of, following, to, by, in, a, were, from,
# Nearest to creation: that, the, of, being, some, their, according, would,
# Nearest to articles: culture, the, by, first, new, history, of, known,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 5.5591 0.0912 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 5.4085 0.0910 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 5.3297 0.0901 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 5.3941 0.0903 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 5.5484 0.0894 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 5.5404 0.0897 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 5.2018 0.0897 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 5.3153 0.0901 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 5.5697 0.0903 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 5.2780 0.0896 sec/batch
# Nearest to years: zero, five, male, age, two, female, year, birth,
# Nearest to most: the, more, has, it, with, as, at, and,
# Nearest to states: united, government, in, countries, economic, state, national, the,
# Nearest to one: six, four, eight, seven, nine, three, two, five,
# Nearest to that: to, a, as, be, have, it, is, or,
# Nearest to more: it, to, as, a, this, is, for, or,
# Nearest to may: not, be, it, to, a, this, that, because,
# Nearest to world: and, united, the, in, at, over, become, of,
# Nearest to bible: hebrew, testament, christians, biblical, christian, scripture, tanakh, canon,
# Nearest to marriage: mother, marry, his, wife, married, divorce, who, christian,
# Nearest to lived: was, who, great, became, founded, name, his, brought,
# Nearest to stage: first, show, at, made, the, on, and, for,
# Nearest to derived: is, there, from, a, forms, it, meaning, called,
# Nearest to taking: by, the, to, has, and, a, in, end,
# Nearest to creation: scientific, their, has, many, as, and, being, that,
# Nearest to articles: and, also, several, most, for, in, well, about,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 5.3124 0.0907 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 5.4666 0.0891 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 5.1895 0.0895 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 5.3353 0.0893 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 5.4299 0.0894 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 5.1718 0.0896 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 5.2225 0.0893 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 5.2986 0.0900 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 5.3247 0.0902 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 5.1778 0.0899 sec/batch
# Nearest to years: one, during, six, two, zero, three, age, four,
# Nearest to most: the, of, and, to, in, with, at, by,
# Nearest to states: state, the, in, united, foreign, european, countries, government,
# Nearest to one: two, three, six, five, seven, four, eight, zero,
# Nearest to that: to, a, be, for, this, it, as, or,
# Nearest to more: this, to, a, it, that, not, is, with,
# Nearest to may: that, a, for, this, to, as, not, is,
# Nearest to world: by, s, the, in, of, and, new, states,
# Nearest to bible: testament, christian, biblical, tanakh, scholars, scripture, prophets, scriptures,
# Nearest to marriage: who, whom, children, his, she, marry, husband, mother,
# Nearest to lived: who, th, until, his, after, was, old, s,
# Nearest to stage: also, for, with, this, first, and, s, as,
# Nearest to derived: is, are, different, these, there, example, usage, have,
# Nearest to taking: which, to, only, this, a, by, always, most,
# Nearest to creation: as, view, that, the, in, of, those, a,
# Nearest to articles: online, encyclopedia, on, review, published, by, also, article,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 5.2921 0.0918 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 5.3491 0.0904 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 5.2151 0.0894 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 5.4784 0.0895 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 5.7230 0.0900 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 5.1129 0.0903 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 5.5175 0.0895 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 5.3183 0.0895 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 5.1817 0.0905 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 5.2637 0.0909 sec/batch
# Nearest to years: zero, male, female, birth, population, age, two, live,
# Nearest to most: the, and, in, to, of, has, on, as,
# Nearest to states: united, union, government, general, state, federal, constitution, nations,
# Nearest to one: nine, six, eight, five, seven, four, three, two,
# Nearest to that: be, this, not, is, or, it, any, they,
# Nearest to more: be, is, it, this, are, or, which, to,
# Nearest to may: it, as, such, to, be, are, a, but,
# Nearest to world: s, year, in, at, was, of, during, became,
# Nearest to bible: scripture, testament, biblical, christian, christ, prophets, prophet, tanakh,
# Nearest to marriage: his, marry, divorce, who, promised, christian, claimed, had,
# Nearest to lived: who, was, late, after, of, his, former, s,
# Nearest to stage: performed, playing, up, on, first, appeared, as, s,
# Nearest to derived: meaning, is, common, this, have, there, are, which,
# Nearest to taking: to, in, the, of, they, a, however, it,
# Nearest to creation: of, them, attempt, in, own, without, as, according,
# Nearest to articles: journal, review, external, encyclopedia, on, online, community, also,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 5.2641 0.0914 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 5.2575 0.0896 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
